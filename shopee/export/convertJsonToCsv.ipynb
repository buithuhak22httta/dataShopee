# %%
import pandas as pd
import os
import json

# %%
f=open('items.json', encoding="utf8")
data = json.load(f)
f.close()
df = pd.DataFrame(data)
df.to_csv('rating.csv', index = False)
df.head(10)
# Out:
#             id                                               name  total  \
# 0   3048464721                             Nệm Lò xo Amando Lucio      9
# 1   4792067949  Gối Foam Doona Extra Gel Cool 35x64cm nâng đỡ ...      2
# 2  14708544545                 Chăn dạ Amando Azalea MP 140x200cm      4
# 3   9877999670  Tấm lót bảo vệ nệm Microfiber Doona làm mềm nệ...     12
# 4   2955216984  Nệm Foam Goodnight Galaxy nguyên tấm kháng khu...     19
# 5   8690830781                 Bảo vệ nệm Doona Bamboo chống thấm     33
# 6   3695318634  Nệm cao su Gummi Standard 100% Thiên Nhiên tho...     35
# 7  10719589936  Tấm lót bảo vệ nệm Doona 01 lớp đủ kích thước,...      5
# 8  11373219330       Chăn chần Amando Promo (nhiều màu) 140x200cm    105
# 9   9954703405  Nệm foam Aeroflow Standard Nhật Bản cao cấp êm...      7
#
#    1 sao  2 sao  3 sao  4 sao  5 sao  \
# 0      0      0      0      0      9
# 1      0      0      0      0      2
# 2      0      0      0      0      4
# ...
